# %% [markdown]
# <a href="https://colab.research.google.com/github/aziziilias/abm/blob/main/analyse_donn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/VincentFavarin/metier.git
# %cd metier
# Out:
# Cloning into 'metier'...
# remote: Enumerating objects: 190, done.
# remote: Counting objects: 100% (190/190), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 190 (delta 104), reused 158 (delta 72), pack-reused 0 (from 0)
# Receiving objects: 100% (190/190), 3.90 MiB | 7.13 MiB/s, done.
# Resolving deltas: 100% (104/104), done.
# /content/metier
